# %%
from PyTDF import *

# %%
use("spark")

# %%
tdf = TDataFrame(filelist=['CMS_Open_Dataset.root'], treename="data")

# %%
chargeCutStr = "C1 != C2"
etaCutStr = "fabs(eta1) < 2.3 && fabs(eta2) < 2.3"
ptCutStr = "pt1 > 2 && pt2 > 2"
tdf_f = tdf.Filter(chargeCutStr, "Opposite Charge") \
           .Filter(etaCutStr, "Central Muons") \
           .Filter(ptCutStr, "Sane Pt")

# %%
# Create the invariant mass column
invMassFormulaStr = "sqrt(pow(E1+E2, 2) - (pow(px1+px2, 2) + pow(py1+py2, 2) + pow(pz1+pz2, 2)))"
tdf_fd = tdf_f.Define("invMass", invMassFormulaStr)#.Filter('cout<<" Event loop running !\\n";')

# Create the histograms
pt1_h = tdf.Histo1D(("","",128,1,1200), "pt1")
pt2_h = tdf.Histo1D(("","",128,1,1200), "pt2")
invMass_h = tdf_fd.Histo1D(("invMass","CMS Opendata;#mu#mu mass [GeV];Events",512,5,110), "invMass")
import ROOT
pi = ROOT.TMath.Pi()
phis_h = tdf_fd.Histo2D(("", "", 64, -pi, pi, 64, -pi, pi), "phi1", "phi2")
# Out:
# Welcome to JupyROOT 6.15/01

# %%
muonsPts = ROOT.TCanvas()
pt1_h.Draw("PL PLC PMC")
pt2_h.Draw("Same PL PLC PMC")
muonsPts.SetLogy()
muonsPts.SetLogx()
muonsPts.Draw()
# Out:
# Distributed execution hasn't been implemented yet !
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in dump(self, obj)
#     147         try:
# --> 148             return Pickler.dump(self, obj)
#     149         except RuntimeError as e:
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in dump(self, obj)
#     408             self.framer.start_framing()
# --> 409         self.save(obj)
#     410         self.write(STOP)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_tuple(self, obj)
#     750         for element in obj:
# --> 751             save(element)
#     752
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     254             if klass is None or klass is not obj:
# --> 255                 self.save_function_tuple(obj)
#     256                 return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     291         save(_make_skel_func)
# --> 292         save((code, closure, base_globals))
#     293         write(pickle.REDUCE)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_tuple(self, obj)
#     735             for element in obj:
# --> 736                 save(element)
#     737             # Subtle.  Same as in the big comment below.
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_appends(self, items)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     254             if klass is None or klass is not obj:
# --> 255                 self.save_function_tuple(obj)
#     256                 return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     291         save(_make_skel_func)
# --> 292         save((code, closure, base_globals))
#     293         write(pickle.REDUCE)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_tuple(self, obj)
#     735             for element in obj:
# --> 736                 save(element)
#     737             # Subtle.  Same as in the big comment below.
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_appends(self, items)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     254             if klass is None or klass is not obj:
# --> 255                 self.save_function_tuple(obj)
#     256                 return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     291         save(_make_skel_func)
# --> 292         save((code, closure, base_globals))
#     293         write(pickle.REDUCE)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_tuple(self, obj)
#     735             for element in obj:
# --> 736                 save(element)
#     737             # Subtle.  Same as in the big comment below.
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_appends(self, items)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     254             if klass is None or klass is not obj:
# --> 255                 self.save_function_tuple(obj)
#     256                 return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     291         save(_make_skel_func)
# --> 292         save((code, closure, base_globals))
#     293         write(pickle.REDUCE)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_tuple(self, obj)
#     735             for element in obj:
# --> 736                 save(element)
#     737             # Subtle.  Same as in the big comment below.
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_appends(self, items)
#     807             elif n:
# --> 808                 save(tmp[0])
#     809                 write(APPEND)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function(self, obj, name)
#     254             if klass is None or klass is not obj:
# --> 255                 self.save_function_tuple(obj)
#     256                 return
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in save_function_tuple(self, func)
#     291         save(_make_skel_func)
# --> 292         save((code, closure, base_globals))
#     293         write(pickle.REDUCE)
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_tuple(self, obj)
#     735             for element in obj:
# --> 736                 save(element)
#     737             # Subtle.  Same as in the big comment below.
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save_list(self, obj)
#     780         self.memoize(obj)
# --> 781         self._batch_appends(obj)
#     782
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in _batch_appends(self, items)
#     804                 for x in tmp:
# --> 805                     save(x)
#     806                 write(APPENDS)
#
# ... last 8 frames repeated, from the frame below ...
#
# /usr/local/Cellar/python/3.6.4_4/Frameworks/Python.framework/Versions/3.6/lib/python3.6/pickle.py in save(self, obj, save_persistent_id)
#     475         if f is not None:
# --> 476             f(self, obj) # Call unbound method with explicit self
#     477             return
#
# RecursionError: maximum recursion depth exceeded in comparison
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# <ipython-input-6-70603771633d> in <module>()
#       1 muonsPts = ROOT.TCanvas()
# ----> 2 pt1_h.Draw("PL PLC PMC")
#       3 pt2_h.Draw("Same PL PLC PMC")
#       4 muonsPts.SetLogy()
#       5 muonsPts.SetLogx()
#
# /usr/local/lib/python3.6/site-packages/PyTDF-0.0.1-py3.6.egg/PyTDF/Proxy.py in _call_handler(self, *args, **kwargs)
#      29             generator = CallableGenerator(self.action_node._get_head())
#      30             executor = Executor()
# ---> 31             executor.execute(generator, Backend_env)
#      32
#      33         return getattr(self.action_node.value, self._cur_attr)(*args, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/PyTDF-0.0.1-py3.6.egg/PyTDF/backend/Executor.py in execute(self, generator, env)
#      31         else:
#      32             from .Dist import dist_executor
# ---> 33             return dist_executor(generator)
#
# /usr/local/lib/python3.6/site-packages/PyTDF-0.0.1-py3.6.egg/PyTDF/backend/Dist.py in dist_executor(generator)
#      16                      npartitions = 2)
#      17
# ---> 18     hList = dTree.ProcessAndMerge(generator.get_callable(), mergeHist)
#      19
#      20     for i in range(len(hList[0])):
#
# /usr/local/lib/python3.6/site-packages/PyTDF-0.0.1-py3.6.egg/PyTDF/backend/DistROOT.py in ProcessAndMerge(self, fMap, fReduce)
#     156         return fReduce(x, y)
#     157
# --> 158     return self.ranges.map(mapWrapper).treeReduce(reduceWrapper)
#     159
#     160   def GetPartitions(self):
#
# /usr/local/lib/python3.6/site-packages/pyspark/rdd.py in treeReduce(self, f, depth)
#     870                 return f(x[0], y[0]), False
#     871
# --> 872         reduced = self.map(lambda x: (x, False)).treeAggregate(zeroValue, op, op, depth)
#     873         if reduced[1]:
#     874             raise ValueError("Cannot reduce empty RDD.")
#
# /usr/local/lib/python3.6/site-packages/pyspark/rdd.py in treeAggregate(self, zeroValue, seqOp, combOp, depth)
#     989                 .values()
#     990
# --> 991         return partiallyAggregated.reduce(combOp)
#     992
#     993     def max(self, key=None):
#
# /usr/local/lib/python3.6/site-packages/pyspark/rdd.py in reduce(self, f)
#     833             yield reduce(f, iterator, initial)
#     834
# --> 835         vals = self.mapPartitions(func).collect()
#     836         if vals:
#     837             return reduce(f, vals)
#
# /usr/local/lib/python3.6/site-packages/pyspark/rdd.py in collect(self)
#     807         """
#     808         with SCCallSiteSync(self.context) as css:
# --> 809             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     810         return list(_load_from_socket(port, self._jrdd_deserializer))
#     811
#
# /usr/local/lib/python3.6/site-packages/pyspark/rdd.py in _jrdd(self)
#    2453
#    2454         wrapped_func = _wrap_function(self.ctx, self.func, self._prev_jrdd_deserializer,
# -> 2455                                       self._jrdd_deserializer, profiler)
#    2456         python_rdd = self.ctx._jvm.PythonRDD(self._prev_jrdd.rdd(), wrapped_func,
#    2457                                              self.preservesPartitioning)
#
# /usr/local/lib/python3.6/site-packages/pyspark/rdd.py in _wrap_function(sc, func, deserializer, serializer, profiler)
#    2386     assert serializer, "serializer should not be empty"
#    2387     command = (func, profiler, deserializer, serializer)
# -> 2388     pickled_command, broadcast_vars, env, includes = _prepare_for_python_RDD(sc, command)
#    2389     return sc._jvm.PythonFunction(bytearray(pickled_command), env, includes, sc.pythonExec,
#    2390                                   sc.pythonVer, broadcast_vars, sc._javaAccumulator)
#
# /usr/local/lib/python3.6/site-packages/pyspark/rdd.py in _prepare_for_python_RDD(sc, command)
#    2372     # the serialized command will be compressed by broadcast
#    2373     ser = CloudPickleSerializer()
# -> 2374     pickled_command = ser.dumps(command)
#    2375     if len(pickled_command) > (1 << 20):  # 1M
#    2376         # The broadcast will have same life cycle as created PythonRDD
#
# /usr/local/lib/python3.6/site-packages/pyspark/serializers.py in dumps(self, obj)
#     462
#     463     def dumps(self, obj):
# --> 464         return cloudpickle.dumps(obj, 2)
#     465
#     466
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in dumps(obj, protocol)
#     702
#     703     cp = CloudPickler(file,protocol)
# --> 704     cp.dump(obj)
#     705
#     706     return file.getvalue()
#
# /usr/local/lib/python3.6/site-packages/pyspark/cloudpickle.py in dump(self, obj)
#     150             if 'recursion' in e.args[0]:
#     151                 msg = """Could not pickle object as excessively deep recursion required."""
# --> 152                 raise pickle.PicklingError(msg)
#     153         except pickle.PickleError:
#     154             raise
#
# PicklingError: Could not pickle object as excessively deep recursion required.
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 18/06/02 01:56:16 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
phis = ROOT.TCanvas()
invMass_h.Draw("col")
phis.Draw()

# %%
tf_count_i = tdf.Count()
tf_count = tdf_f.Count()
print(tf_count.GetValue())
print(tf_count_i.GetValue())

# %%
muonsPts = ROOT.TCanvas()
pt1_h.Draw("PL PLC PMC")
pt2_h.Draw("Same PL PLC PMC")
muonsPts.SetLogy()
muonsPts.SetLogx()
muonsPts.Draw()

# %%
phis = ROOT.TCanvas()
invMass_h.Draw("col")
phis.Draw()
